# %%
import tweepy
from tweepy import API
from tweepy import Cursor
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler 
from tweepy import Stream
import numpy as np 
import pandas as pd

# %%
access_token= '1261021151754682375-WFJgum4dUxrErkxUzLabrGitnYQPgj'
access_token_secret = 'sBiyzO60LzMwDC7X6x2XaJBRcoPOzxT7JDypbcptHD1Ob'
consumer_key = 'i73CZaLFIv2iuzUSWwAZ4n3qj'
consumer_secret = 'Za4BuBZEL8sGPwKq2kDZsS5vieG8qvH0bdgBWM2OdbjOi5Root'

# %%
auth= tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api=tweepy.API(auth)

# %%
for tweet in api.search('iPhone'):
    print(tweet)
# Out:
# Status(_api=<tweepy.api.API object at 0x000001DFFAE06430>, _json={'created_at': 'Tue Aug 10 08:48:44 +0000 2021', 'id': 1425016252238471170, 'id_str': '1425016252238471170', 'text': 'RT @chitaglorya: giveaway 300$ | 4,200,000 IDR \niphone 8plus for one winner 💥\n\n- retweet follow me &amp; \n\n@cryptotahid\n\n@cryptovenizo\n\nends in…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'chitaglorya', 'name': 'chita🍒', 'id': 1334937336690327552, 'id_str': '1334937336690327552', 'indices': [3, 15]}, {'screen_name': 'cryptotahid', 'name': 'Crypto Giveaways 🐺', 'id': 1949559619, 'id_str': '1949559619', 'indices': [107, 119]}, {'screen_name': 'cryptovenizo', 'name': 'Crypto Venizo 🚀', 'id': 1072139057986039808, 'id_str': '1072139057986039808', 'indices': [121, 134]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', '
# ...

# %%
for tweet in api.search('iPhone'):
    print (tweet.text)
# Out:
# RT @jiims: GIVEAWAY BRANDNEW IPHONE | 10 DAYS ! 😻✨
#
# must be following me &amp;
# @cryptonning , @cryptoethereal
# RT + tag mutuals! https://t.co/40…
# RT @chitaglorya: giveaway 300$ | 4,200,000 IDR
# iphone 8plus for one winner 💥
#
# - retweet follow me &amp;
#
# @cryptotahid
#
# @cryptovenizo
#
# ends in…
# マイクの件なんだけど昨日ようやくマイク正常に動きまして...
# それまでマイク認識してなかった笑。iPhoneの内蔵マイクをずっと使ってたという。切ない。
#
# 配線も複雑で助けてもらいながらなんとか完成してよかった...
# RT @takegiveson: 📱第21回 iPhone勢支援企画📱
#
# 夏の還元祭 vol.2🌻
#
# iPad Pro 1TB+Magic keybordかpencil
# →2名🎁
#
# iTunesカード10000円分
# →1名🎁
#
# ・@takegiveson をフォロー
# ・このツイ…
# RT @DIPROMOSIKAN: 【ＲＥＴＷＥＥＴ】 #TFBJP
# #TEAMFOLLOWBACK
# #TEAMFOLLOWWACK #IPHONE
# #1000ADAY #TEAMHITFOLLOW #Follow
# #OPENFOLLOW #Mustfollow #IPOD…
# RT @jaemcityx: GIVEAWAY $300 | 4.1 JUTA RUPIAH | IPHONE 8 FOR ONE WINNER !!
#
# - rt follow me and
#
# @promotionfairy
# @YnahGives
# @RemiPromotes…
# モイ！iPhoneからキャス配信中 - / ぱお https://t.co/7citL1ImMm
# 青スライドが速すぎるからiPhoneでやったほうが繋ぎやすいかもなあ
# ...

# %%
df = pd.DataFrame(columns = ['Tweets','Tweet_id','User', 'User_id', 'User_statuses_count', 'User followers', 'User_friends_count', 'User_location', 'fav_count', 'rt_count',
'tweet_date', 'User_verified'])

# %%
def stream(data, file_name):
    i=0
    for tweet in tweepy. Cursor(api.search, q=data, count=100, lang='en').items():
        print (i, end='\r')
        df.loc[i, 'Tweets'] = tweet.text 
        df.loc[i, 'Tweet_id'] = tweet.id
        #df. Loc[i, Hashtags'] = tweet. entities.hashtags
        df.loc[i, 'User'] = tweet.user.name
        df.loc[i, 'User_id'] = tweet.user.id
        df.loc[i, 'User_statuses_count'] = tweet.user.statuses_count 
        df.loc[i, 'User_followers'] = tweet.user.followers_count
        df.loc[i, 'User_friends_count']=tweet.user.friends_count
        df.loc[i, 'User_location'] = tweet.user.location
        df.loc[i, 'fav_count'] = tweet.favorite_count
        df.loc[i, 'rt_count'] = tweet.retweet_count
        df.loc[i, 'tweet_date'] = tweet.created_at
        df.loc[i, 'User_verified'] = tweet.user.verified
        df.to_csv('{}.csv'.format(file_name))
        i+=1
        if i== 2000:
               break
        else:
               pass

# %%
 stream(data = ['iPhoneX'], file_name = 'my_tweets_2k')
# Out:
# 418

# %%
df.head()
# Out:
#                                               Tweets             Tweet_id  \
# 0                        @O629_k_ iPhoneSE＋iPhoneX＝？  1425014174069886985
# 1  @kjenslave Legit plus pre debut haruto his own...  1425003186666885120
# 2  @Apple hi iam using iPhoneX. I was updated iOS...  1425001795512717317
# 3  RT @Qu_entinD: SERIES =&gt; Today is a new wal...  1424989217936060433
# 4  Blender Timelapse | modeling and rendering iPh...  1424974306199576577
#
#              User              User_id User_statuses_count User followers  \
# 0        オーロラリティー  1263153611007115265                 275            NaN
# 1  Prince Haruto🦋  1265638750337429504                6260            NaN
# 2          pasith  1164923482662211584                  14            NaN
# 3          DomCub  1238179956611571718                2468            NaN
# 4            Bram           3312108100                6410            NaN
#
#   User_friends_count                   User_location fav_count rt_count  \
# ...

# %%
from textblob import TextBlob 
from wordcloud import WordCloud, STOPWORDS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-56-e5a01fa5208a> in <module>
#       1 from textblob import TextBlob
# ----> 2 from wordcloud import WordCloud, STOPWORDS
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
import re
def clean_tweet (tweet):
    return ' '.join(re.sub('(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)| (https?:\/\/.*[\r\n]*)','',tweet).split())

# %%
def analyze_sentiment (tweet):
    analysis = TextBlob(tweet)
    if analysis. sentiment.polarity > 8: return 4
    elif analysis. sentiment.polarity ==0:
        return '2'
    else:
        return 'e'

# %%
df['clean_tweet'] = df[ 'Tweets'].apply(lambda x: clean_tweet(x)) 
df['Sentiment'] = df[ 'clean_tweet'].apply(lambda x: analyze_sentiment (x))

# %%
n=12 
print ('Original tweet: \n' + df['Tweets'][n]) 
print() 
print('Clean tweet:\n'+df['clean_tweet'][n]) 
print() 
print('Sentiment:\n'+df[ 'Sentiment' ][n])
# Out:
# Original tweet:
# @ItsSKhan22 @Amph1trit3 The iPhone 8 was an outlier. Apples 2017 flagship was the iPhone X (10th anniversary phone)… https://t.co/De1f5Z5Nhd
#
# Clean tweet:
# The iPhone 8 was an outlier Apples 2017 flagship was the iPhone X 10th anniversary phone
#
# Sentiment:
# 2

# %%
print(df['Sentiment'].unique ())
#df['Sentiment']=df['Sentiment'].astype(int) 
print(df['Sentiment'].unique())
print(df['Sentiment'].value_counts())
# Out:
# ['2' 'e']
# ['2' 'e']
# 2    235
# e    184
# Name: Sentiment, dtype: int64

# %%
all_tweets=''.join(tweet for tweet in df['clean_tweet'])

# %%
#wordcloud WordCloud (stopwords=STOPWORDS).generate (all_tweets)

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
plt.figure(figsize (10,10))
plt.imshow (wordcloud, interpolation='bilinear")
plt.axis("off")
plt.show(
# Out:
#   File "<ipython-input-88-c0064d309ac0>", line 3
#     plt.imshow (wordcloud, interpolation='bilinear")
#                                                     ^
# SyntaxError: EOL while scanning string literal

# %%
df_freq pd.DataFrame.from_dict(data=wordcloud.word_,orinet='index')
df_freq=df_freq.head (20) 
df_freq.plot.bar()
# Out:
#   File "<ipython-input-89-09a7d35b8d3e>", line 1
#     df_freq pd.DataFrame.from_dict(data=wordcloud.word_,orinet='index')
#             ^
# SyntaxError: invalid syntax

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 419 entries, 0 to 418
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Tweets               419 non-null    object
#  1   Tweet_id             419 non-null    object
#  2   User                 419 non-null    object
#  3   User_id              419 non-null    object
#  4   User_statuses_count  419 non-null    object
#  5   User followers       0 non-null      object
#  6   User_friends_count   419 non-null    object
#  7   User_location        419 non-null    object
#  8   fav_count            419 non-null    object
#  9   rt_count             419 non-null    object
#  10  tweet_date           419 non-null    object
#  11  User_verified        419 non-null    object
#  12  User_followers       419 non-null    float64
#  13  clean_tweet          419 non-null    object
#  14  Sentiment            419 non-null    object
# ...

# %%
print (df['User_location'].unique())
# Out:
# ['→waseda?' '' 'Frankfurt am Main, Deutschland' 'Rotterdam, Zuid-Holland'
#  'North Western, Zambia' 'Los Angeles, CA' 'USA' 'Japan' 'ilesha,Nigeria'
#  'Ghana' 'Greater Accra, Ghana' 'Prampram ' '♡🐈🐈♡' 'New York' 'Canada'
#  'Richmond Hill Ontario, Canada' 'The Phynest' 'Mind Your Business'
#  'Greater Accra, Ghana ' 'Near us' 'IDIOT,GO AHEAD AND BLOCK ME'
#  'Adenta, Accra ' 'United States' 'France' 'Bengaluru, India' 'usa'
#  'Indonesia' '八王子の玉座' 'Auckland, New Zealand' 'Kumasi, Ghana📍'
#  'Taichung City, Taiwan' 'Ahmadabad City, Gujarat' '新潟'
#  'Dilli hai meri jaan' 'Edinburgh, Scotland' 'Shenzhen,China'
#  'आज़मगढ़, भारत' 'Turín - Italia' 'Edinburgh ' 'Seoul, Korea'
#  'Stockholm, Suède' 'Buston, USA' 'California, USA' 'Chicago, USA' 'Earth'
#  'Lagos, Nigeria ' 'Multan, Pakistan' 'Montevideo, Uruguay' 'Florida, USA'
#  'Bedford, MA' 'Bwari, Nigeria' 'EARTH' 'Toronto, Ontario' 'shah alam'
#  '#LindseyGrahamIsGAY' 'Dhaka, Bangladesh' 'Rio de janeiro'
# ...

# %%
df['User_statuses_count'] = df['User_statuses_count'].astype (int)
df['User_followers'] = df['User_followers'].astype(int)
df[ 'User_friends_count'] = df [ 'User_friends_count'].astype (int) 
df['rt_count'] = df['rt_count'].astype (int)
df[ 'fav_count'] = df['fav_count'].astype (int)
df['tweet_date_mod'] = pd.to_datetime(df['tweet_date'], format='[%d/%b/%Y: %H:%M:%S]') 
# set date time to pandas datatime obj
df =df.drop(['tweet_date'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 419 entries, 0 to 418
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Tweets               419 non-null    object
#  1   Tweet_id             419 non-null    object
#  2   User                 419 non-null    object
#  3   User_id              419 non-null    object
#  4   User_statuses_count  419 non-null    int32
#  5   User followers       0 non-null      object
#  6   User_friends_count   419 non-null    int32
#  7   User_location        419 non-null    object
#  8   fav_count            419 non-null    int32
#  9   rt_count             419 non-null    int32
#  10  User_verified        419 non-null    object
#  11  User_followers       419 non-null    int32
#  12  clean_tweet          419 non-null    object
#  13  Sentiment            419 non-null    object
#  14  tweet_date_mod       419 non-null    datetime64[ns]
# ...

# %%
print(df['User_statuses_count'].unique()) 
print(df['User_statuses_count'].value_counts())
# Out:
# [    275    6260      14    2468    6410     290  302068    4496   67982
#     4094    3587       1    1011  121912   11371    1682  118876    9112
#        5   33648     845   45637  105884  151964   77483     760  216743
#    58312    2053   85204      12   16849    4151    3762  436032  152457
#       10     167   34876      11    1014   10765     270   14232     190
#     2691   17909 1545538    2479   25950  584826   71303      88   50281
#       59    1663   76943    3934      60   11787   48360    5032    1101
#     6958      78      40    1683      97    8552     139     450       3
#   138899    1258   91795     206     981   77952  108589    6765   49098
#     2250   22919    4070      86  494164    4026     476   11243      39
#      209  108382      61    2278   62886   20193   43669   10851    1967
#    95382  201864     214   18394   38206   39410    7373   13051   15500
#    70852    7101  225247   12519    9472   84229   11960     991   16760
# ...

# %%
import seaborn as sns
dg=sns.distplot(df['rt_count'].dropna ())
plt.show()
# Out:
# c:\users\welcome\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
dg=sns.countplot(data=df, x='User_statuses_count')
plt.show()

# %%
sns.boxplot(x="Sentiment", y="fav_count", data=df)
plt.show()

sns.boxplot(x="Sentiment", y="rt_count", data=df) 
plt.show()

# %%
#import pyspark modules
from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
from pyspark.sql.types import *
from pyspark.sql.functions import *
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.feature import HashingTF, Tokenizer, StopWordsRemover
#create Spark session
appName = "Sentiment Analysis in Spark"
spark = SparkSession \
  .builder \
  .appName(appName) \
  .config("spark.some.config.option", "some-value") \
  .getOrCreate()

# %%
tweets_csv =spark.createDataFrame(df) 
tweets_csv.printSchema () 
tweets_csv.show(truncate=False, n=5)
# Out:
# root
#  |-- Tweets: string (nullable = true)
#  |-- Tweet_id: long (nullable = true)
#  |-- User: string (nullable = true)
#  |-- User_id: long (nullable = true)
#  |-- User_statuses_count: long (nullable = true)
#  |-- User followers: double (nullable = true)
#  |-- User_friends_count: long (nullable = true)
#  |-- User_location: string (nullable = true)
#  |-- fav_count: long (nullable = true)
#  |-- rt_count: long (nullable = true)
#  |-- User_verified: boolean (nullable = true)
#  |-- User_followers: long (nullable = true)
#  |-- clean_tweet: string (nullable = true)
#  |-- Sentiment: string (nullable = true)
#  |-- tweet_date_mod: timestamp (nullable = true)
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-137-de464085d10d> in <module>
#       1 tweets_csv =spark.createDataFrame(df)
#       2 tweets_csv.printSchema ()
# ...

# %%
tweets_csv.describe().toPandas().transpose()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-135-4aae0946eb6a> in <module>
# ----> 1 tweets_csv.describe().toPandas().transpose()
#
# c:\users\welcome\appdata\local\programs\python\python39\lib\site-packages\pyspark\sql\dataframe.py in describe(self, *cols)
#    1489         if len(cols) == 1 and isinstance(cols[0], list):
#    1490             cols = cols[0]
# -> 1491         jdf = self._jdf.describe(self._jseq(cols))
#    1492         return DataFrame(jdf, self.sql_ctx)
#    1493
#
# c:\users\welcome\appdata\local\programs\python\python39\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# ...

# %%
#selecting clean_tweets and SentimentLabel variables
data=tweets_csv.select("clean_tweet", col("Sentiment").cast("Int").alias("label"))
data.show(truncate=False,n=10)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-128-031fb61a70ea> in <module>
#       1 #selecting clean_tweets and SentimentLabel variables
#       2 data=tweets_csv.select("clean_tweet", col("Sentiment").cast("Int").alias("label"))
# ----> 3 data.show(truncate=False,n=10)
#
# c:\users\welcome\appdata\local\programs\python\python39\lib\site-packages\pyspark\sql\dataframe.py in show(self, n, truncate, vertical)
#     484             print(self._jdf.showString(n, 20, vertical))
#     485         else:
# --> 486             print(self._jdf.showString(n, int(truncate), vertical))
#     487
#     488     def __repr__(self):
#
# c:\users\welcome\appdata\local\programs\python\python39\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# ...

# %%
#divide data, 70% for training, 30% for testing
dividedData = data.randomSplit([0.7, 0.3])
trainingData = dividedData [0] #index 0 data training
testingData = dividedData[1] #index 1 = data testing
train_rows = trainingData.count()
test_rows = testingData.count()
print ("Training data rows:", train_rows, "; Testing data rows:", test_rows)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-127-eba7289cd88c> in <module>
#       3 trainingData = dividedData [0] #index 0 data training
#       4 testingData = dividedData[1] #index 1 = data testing
# ----> 5 train_rows = trainingData.count()
#       6 test_rows = testingData.count()
#       7 print ("Training data rows:", train_rows, "; Testing data rows:", test_rows)
#
# c:\users\welcome\appdata\local\programs\python\python39\lib\site-packages\pyspark\sql\dataframe.py in count(self)
#     662         2
#     663         """
# --> 664         return int(self._jdf.count())
#     665
#     666     def collect(self):
#
# c:\users\welcome\appdata\local\programs\python\python39\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# ...

# %%
tokenizer Tokenizer (inputCol="clean_tweet", output Col="Sentimentwords"
tokenizedTrain tokenizer.transform(trainingData) 
tokenizedTrain.show(truncate=False, n=5)

# %%
Swr = StopWordsRemover (inputCol=tokenizer.getOutputCol(), outputCol="Meaningfulwords") 
SwRemoved Train=swr.transform(tokenizedTrain) = SwRemoved 
rain.show(truncate=False, n=5)

# %%
hashTF = HashingTF (inputCol-swr.getOutputCol(), outputCol="features")
numericTrainData hashTF.transform(SwRemoved Train).select('label', 'Meaningfulwords', 'features')
numericTrainData.show(truncate=False, n=5)

# %%
lr = LogisticRegression (labelCol="label", featuresCol="features", maxIter-10, regParam=0.01) 
model = lr.fit(numeric TrainData) 
print ("Iraining is done!")

# %%
tokenized Test = tokenizer.transform(testingData) 
SwRemoved Test = swr.transform(tokenizedTest) numericTest = hashTF.transform 
(SwRemovedTest).select( 'label', 'MeaningfulWords', 'features') 
numericTest.show(truncate=False, n=5)

# %%
prediction = model.transform(numeric Test)

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator 
evaluator=MulticlassClassificationEvaluator (predictionCol="prediction") 
evaluator.evaluate(prediction)

# %%
predictionFinal prediction.select( "Meaningfulwords", "prediction", "label")
predictionFinal.show(n=20, truncate = False)
correctPrediction = predictionFinal.filter( predictionFinal['prediction'] == prediction Final['label']).count() 
totalData = predictionFinal.count() 
print("correct prediction:", correct Prediction,", total data: ", totalData, accuracy:", correct Prediction/totalData)

# %%
#!pip install --user --upgrade pixiedust
import pixiedust
from pixiedust.display import *

# %%
display (predictionFinal)

# %%
from pyspark.ml.classification import NaiveBayes
nb NaiveBayes (smoothing=1)
model2 nb.fit(numericTrainData)
print ("Model is trained!"

# %%
prediction=model2.transform(numeric Test)
predictionFinal2= prediction.select"Meaningfulwords", "prediction", "label")
predictionFinal2.show(n=20, truncate = False) 
correctPrediction predictionFinal2.filter(
predictionFinal2['prediction'] predictionFinal2['label']).count() 
totalData predictionFinal2.count()
print("correct prediction:", correct Prediction, total data:", totalData, ", accuracy:", correctPrediction/totalData)

I

# %%
display(predictionFinall2)

# %%
from pyspark.ml.classification import RandomForestClassifier

rfc = RandomForestClassifier( numTrees=3, maxDepth=5, seed-42, labelcol="label", featuresCol "features") 
model3 = rfc.fit(numeric TrainData)
print ("Model is trained!")

# %%
predictionmodel3.transform(numeric Test) predictionFinal3 = prediction.select("Meaningfulwords", "prediction", Tabel") predictionFinal3.show(n=20, truncate=False)
correctPrediction=predictionFinal3.filter(
predictionFinal3['prediction'] == predictionFinal3["label]).count()
totalData predictionFinal3.count()
print("correct prediction:", correct Prediction, ", total data", totalData,", accuracy:", correct Prediction/totalData)

# %%
display(predictionFinall3)

# %%
from pyspark.ml.clustering import LDA
# Generate 7 Data-Driven Topics:
# "em" = expectation-maximization
lda = LDA (k=7, maxIter-10, featuresCol= "features") model = lda. fit (numeric Test)

# A model with higher Log-Likelihood and Lower perplexity is considered to be good.
ll= model.logLikelihood (numeric Test) lp model.logPerplexity (numeric Test)
print("The lower bound on the log likelihood of the entire corpus: " + str(ll)) print("The upper bound on perplexity: + str(lp))

# Describe topics.
topics model.describeTopics (7) =
print("The topics described by their top-weighted terms:")
topics.show(truncate=False)

# Shows the result
transformed = model.transform(numericTest)
print (transformed.show())
print (transformed.show(trincate=False))

# %%
topn_ words 10
num_topics = 7
topics= model.topicsMatrix().toArray()
for topic in range(num_topics):
print("Topic + str(topic) + ":") for word in range(0, topn_words):
print(" + str(topics [word] [topic])

# %%
from pyspark.ml.clustering import KMeans from pyspark.ml.feature import VectorAssembler
#define assembler
assembler VectorAssembler (inputCols ['User_statuses_count', 'User_followers', 'User_friends_count'], = output Col="features")
data assembler.transform(tweets_csv).select('User', 'features') 
data.show(truncate False, n=3) 
data.count()

# %%
cost np.zeros(20)
for k in range (2,20):
kmeans KMeans().setk(k).setSeed (1). setFeatures Col("features")
model kmeans.fit (data.sample(False, 0.1, seed=42))
cost [k] model.computeCost(data) # requires Spark 2.0 or Later

# %%
fig, ax = plt.subplots (1,1, figsize =(8,6))
ax.plot(range (2,20), cost[2:20])
ax.set_xlabel('k')
ax.set_ylabel('cost')

# %%
#define kMeans clustering algorithm
kmeans - KMeans(
featuresCol-assembler.getOutputCol(),
predictionCol="cluster", k=6)
model = kmeans.fit(data)
print ("Model is successfully trained!")

# %%
centers = model.clusterCenters()
print("Cluster Centers: ") 
for center in centers: 
    print(center)

# %%
transformed model.transform(data). select('User', 'cluster')
rows transformed.collect() 
print (rows[:3])

# %%
df_pred spark.createDataFrame(rows) 
df_pred.show()

# %%
df = tweets_csv[['User', 'User_statuses_count', 'User_followers', 'User_friends_count']]
df_pred df_pred.join(df, 'User') 
df_pred.show()

# %%
pddf_pred=df_pred.toPandas().set_index('User')
pddf_pred.head()

# %%
import matplotlib.pyplot as plt 
from mp1_toolkits.mplot3d import Axes 3D 
# %matplotlib inline
threedee = plt.figure(figsize=(12,10)).gca (projection="3d')
threedee.scatter(pddf_pred.User_statuses_count, pddf_pred.User_followers, pddf_pred. User_friends_count, c-pddf_pred.cluster) 
threedee.set_xlabel('User_statuses_count") 
threedee.set_ylabel('User_followers) 
threedee.set_zlabel('User_friends_count)

# %%
plt.figure()
pd.tools.plotting.parallel_coordinates(
  pddf_pred[['cluster', 'User_statuses_count', 'User_followers', 'User_friends_count']],'cluster')
plt.show()

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import plotly
plotly.tools.set_credentials_file(username='Drashtiba', api_key='25XpKdAvVmLa63PCm3w2')

data = [
   go.Parcoords(
     line = dict (color = pddf_pred['cluster'],
        colorscale = [[0, #D7C16B'],[0.5, #23D8C3'],[1, '#F3F10F']]),
     dimensions = list([
       dict (range = [0,5000],
           constraintrange = [4,8],
             label = User_statuses_count', values = pddf_pred['User_statuses_cours']),
       dict (range = [0,5000], 
             label = 'User_followers', values = pddf_pred[ 'User_followers']),
        dict (range = [0,5000],
            label="User friends _count', values pddf_pred[ 'User_friends_count']),
      dict (range = [0,5],
           label = cluster', values = pddf_pred['cluster'])
      ]) )

# %%
#pairplot the cluster distribution.
cluster_g sns.pairplot (pddf_pred, hue='cluster')
plt.show()

# %%
spark.stop()
